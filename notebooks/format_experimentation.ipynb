# %%
import pyarrow as pa
import pyarrow.parquet as pq

parquet_file = pq.ParquetFile("../data/corpus/cleaned_msmarco-docs.parquet")
arrow_table = parquet_file.read()
print("Loaded Arrow Table")

pq.write_table(
    arrow_table,
    "../data/corpus/dataset.parquet",
    row_group_size=10000
)

print(f"Original number of row groups: {parquet_file.num_row_groups}")

new_parquet_file = pq.ParquetFile("../data/corpus/dataset.parquet")
print(f"New number of row groups: {new_parquet_file.num_row_groups}")
# Out:
# Loaded Arrow Table
# Original number of row groups: 108
# New number of row groups: 288

# %%
import pyarrow.parquet as pq
import polars as pl

parquet_file_path = "../data/corpus/dataset.parquet"  # Path to your Parquet file
lookup_file_path = "../data/train/docid_lookup.parquet"  # Path to save the lookup dataset
row_group_size = 10000  # Row group size used in the Parquet file

# Load the Parquet file
parquet_file = pq.ParquetFile(parquet_file_path)

# Initialize the lookup data
lookup_data = []

# Iterate over each row group
for row_group_index in range(parquet_file.num_row_groups):
    # Read the current row group
    row_group = parquet_file.read_row_group(row_group_index, columns=["docid"])
    
    # Convert to Polars DataFrame
    row_group_df = pl.from_arrow(row_group)
    
    # Add row group index to each docid
    lookup_data.append(
        row_group_df.with_columns(pl.lit(row_group_index).alias("row_group"))
    )
    print(f"Added row group {row_group_index} to lookup data")
# Concatenate all row group lookup data into a single Polars DataFrame
lookup_df = pl.concat(lookup_data)

# Save the lookup dataset as a Parquet file
lookup_df.write_parquet(lookup_file_path)

print(f"Lookup dataset created and saved to {lookup_file_path}")
# Out:
# Added row group 0 to lookup data
# Added row group 1 to lookup data
# Added row group 2 to lookup data
# Added row group 3 to lookup data
# Added row group 4 to lookup data
# Added row group 5 to lookup data
# Added row group 6 to lookup data
# Added row group 7 to lookup data
# Added row group 8 to lookup data
# Added row group 9 to lookup data
# Added row group 10 to lookup data
# Added row group 11 to lookup data
# Added row group 12 to lookup data
# Added row group 13 to lookup data
# Added row group 14 to lookup data
# Added row group 15 to lookup data
# Added row group 16 to lookup data
# Added row group 17 to lookup data
# Added row group 18 to lookup data
# Added row group 19 to lookup data
# Added row group 20 to lookup data
# Added row group 21 to lookup data
# Added row group 22 to lookup data
# Added row group 23 to lookup data
# Added row group 24 to lookup data
# Added row group 25 to lookup data
# Added row group 26 to lookup data
# Added row group 27 to lookup data
# Added row group 28 to lookup data
# Added row group 29 to lookup data
# Added row group 30 to lookup data
# Added row group 31 to lookup data
# Added row group 32 to lookup data
# Added row group 33 to lookup data
# Added row group 34 to lookup data
# Added row group 35 to lookup data
# Added row group 36 to lookup data
# Added row group 37 to lookup data
# Added row group 38 to lookup data
# Added row group 39 to lookup data
# Added row group 40 to lookup data
# Added row group 41 to lookup data
# Added row group 42 to lookup data
# Added row group 43 to lookup data
# Added row group 44 to lookup data
# Added row group 45 to lookup data
# Added row group 46 to lookup data
# Added row group 47 to lookup data
# Added row group 48 to lookup data
# Added row group 49 to lookup data
# Added row group 50 to lookup data
# Added row group 51 to lookup data
# Added row group 52 to lookup data
# Added row group 53 to lookup data
# Added row group 54 to lookup data
# Added row group 55 to lookup data
# Added row group 56 to lookup data
# Added row group 57 to lookup data
# Added row group 58 to lookup data
# Added row group 59 to lookup data
# Added row group 60 to lookup data
# Added row group 61 to lookup data
# Added row group 62 to lookup data
# Added row group 63 to lookup data
# Added row group 64 to lookup data
# Added row group 65 to lookup data
# Added row group 66 to lookup data
# Added row group 67 to lookup data
# Added row group 68 to lookup data
# Added row group 69 to lookup data
# Added row group 70 to lookup data
# Added row group 71 to lookup data
# Added row group 72 to lookup data
# Added row group 73 to lookup data
# Added row group 74 to lookup data
# Added row group 75 to lookup data
# Added row group 76 to lookup data
# Added row group 77 to lookup data
# Added row group 78 to lookup data
# Added row group 79 to lookup data
# Added row group 80 to lookup data
# Added row group 81 to lookup data
# Added row group 82 to lookup data
# Added row group 83 to lookup data
# Added row group 84 to lookup data
# Added row group 85 to lookup data
# Added row group 86 to lookup data
# Added row group 87 to lookup data
# Added row group 88 to lookup data
# Added row group 89 to lookup data
# Added row group 90 to lookup data
# Added row group 91 to lookup data
# Added row group 92 to lookup data
# Added row group 93 to lookup data
# Added row group 94 to lookup data
# Added row group 95 to lookup data
# Added row group 96 to lookup data
# Added row group 97 to lookup data
# Added row group 98 to lookup data
# Added row group 99 to lookup data
# Added row group 100 to lookup data
# Added row group 101 to lookup data
# Added row group 102 to lookup data
# Added row group 103 to lookup data
# Added row group 104 to lookup data
# Added row group 105 to lookup data
# Added row group 106 to lookup data
# Added row group 107 to lookup data
# Added row group 108 to lookup data
# Added row group 109 to lookup data
# Added row group 110 to lookup data
# Added row group 111 to lookup data
# Added row group 112 to lookup data
# Added row group 113 to lookup data
# Added row group 114 to lookup data
# Added row group 115 to lookup data
# Added row group 116 to lookup data
# Added row group 117 to lookup data
# Added row group 118 to lookup data
# Added row group 119 to lookup data
# Added row group 120 to lookup data
# Added row group 121 to lookup data
# Added row group 122 to lookup data
# Added row group 123 to lookup data
# Added row group 124 to lookup data
# Added row group 125 to lookup data
# Added row group 126 to lookup data
# Added row group 127 to lookup data
# Added row group 128 to lookup data
# Added row group 129 to lookup data
# Added row group 130 to lookup data
# Added row group 131 to lookup data
# Added row group 132 to lookup data
# Added row group 133 to lookup data
# Added row group 134 to lookup data
# Added row group 135 to lookup data
# Added row group 136 to lookup data
# Added row group 137 to lookup data
# Added row group 138 to lookup data
# Added row group 139 to lookup data
# Added row group 140 to lookup data
# Added row group 141 to lookup data
# Added row group 142 to lookup data
# Added row group 143 to lookup data
# Added row group 144 to lookup data
# Added row group 145 to lookup data
# Added row group 146 to lookup data
# Added row group 147 to lookup data
# Added row group 148 to lookup data
# Added row group 149 to lookup data
# Added row group 150 to lookup data
# Added row group 151 to lookup data
# Added row group 152 to lookup data
# Added row group 153 to lookup data
# Added row group 154 to lookup data
# Added row group 155 to lookup data
# Added row group 156 to lookup data
# Added row group 157 to lookup data
# Added row group 158 to lookup data
# Added row group 159 to lookup data
# Added row group 160 to lookup data
# Added row group 161 to lookup data
# Added row group 162 to lookup data
# Added row group 163 to lookup data
# Added row group 164 to lookup data
# Added row group 165 to lookup data
# Added row group 166 to lookup data
# Added row group 167 to lookup data
# Added row group 168 to lookup data
# Added row group 169 to lookup data
# Added row group 170 to lookup data
# Added row group 171 to lookup data
# Added row group 172 to lookup data
# Added row group 173 to lookup data
# Added row group 174 to lookup data
# Added row group 175 to lookup data
# Added row group 176 to lookup data
# Added row group 177 to lookup data
# Added row group 178 to lookup data
# Added row group 179 to lookup data
# Added row group 180 to lookup data
# Added row group 181 to lookup data
# Added row group 182 to lookup data
# Added row group 183 to lookup data
# Added row group 184 to lookup data
# Added row group 185 to lookup data
# Added row group 186 to lookup data
# Added row group 187 to lookup data
# Added row group 188 to lookup data
# Added row group 189 to lookup data
# Added row group 190 to lookup data
# Added row group 191 to lookup data
# Added row group 192 to lookup data
# Added row group 193 to lookup data
# Added row group 194 to lookup data
# Added row group 195 to lookup data
# Added row group 196 to lookup data
# Added row group 197 to lookup data
# Added row group 198 to lookup data
# Added row group 199 to lookup data
# Added row group 200 to lookup data
# Added row group 201 to lookup data
# Added row group 202 to lookup data
# Added row group 203 to lookup data
# Added row group 204 to lookup data
# Added row group 205 to lookup data
# Added row group 206 to lookup data
# Added row group 207 to lookup data
# Added row group 208 to lookup data
# Added row group 209 to lookup data
# Added row group 210 to lookup data
# Added row group 211 to lookup data
# Added row group 212 to lookup data
# Added row group 213 to lookup data
# Added row group 214 to lookup data
# Added row group 215 to lookup data
# Added row group 216 to lookup data
# Added row group 217 to lookup data
# Added row group 218 to lookup data
# Added row group 219 to lookup data
# Added row group 220 to lookup data
# Added row group 221 to lookup data
# Added row group 222 to lookup data
# Added row group 223 to lookup data
# Added row group 224 to lookup data
# Added row group 225 to lookup data
# Added row group 226 to lookup data
# Added row group 227 to lookup data
# Added row group 228 to lookup data
# Added row group 229 to lookup data
# Added row group 230 to lookup data
# Added row group 231 to lookup data
# Added row group 232 to lookup data
# Added row group 233 to lookup data
# Added row group 234 to lookup data
# Added row group 235 to lookup data
# Added row group 236 to lookup data
# Added row group 237 to lookup data
# Added row group 238 to lookup data
# Added row group 239 to lookup data
# Added row group 240 to lookup data
# Added row group 241 to lookup data
# Added row group 242 to lookup data
# Added row group 243 to lookup data
# Added row group 244 to lookup data
# Added row group 245 to lookup data
# Added row group 246 to lookup data
# Added row group 247 to lookup data
# Added row group 248 to lookup data
# Added row group 249 to lookup data
# Added row group 250 to lookup data
# Added row group 251 to lookup data
# Added row group 252 to lookup data
# Added row group 253 to lookup data
# Added row group 254 to lookup data
# Added row group 255 to lookup data
# Added row group 256 to lookup data
# Added row group 257 to lookup data
# Added row group 258 to lookup data
# Added row group 259 to lookup data
# Added row group 260 to lookup data
# Added row group 261 to lookup data
# Added row group 262 to lookup data
# Added row group 263 to lookup data
# Added row group 264 to lookup data
# Added row group 265 to lookup data
# Added row group 266 to lookup data
# Added row group 267 to lookup data
# Added row group 268 to lookup data
# Added row group 269 to lookup data
# Added row group 270 to lookup data
# Added row group 271 to lookup data
# Added row group 272 to lookup data
# Added row group 273 to lookup data
# Added row group 274 to lookup data
# Added row group 275 to lookup data
# Added row group 276 to lookup data
# Added row group 277 to lookup data
# Added row group 278 to lookup data
# Added row group 279 to lookup data
# Added row group 280 to lookup data
# Added row group 281 to lookup data
# Added row group 282 to lookup data
# Added row group 283 to lookup data
# Added row group 284 to lookup data
# Added row group 285 to lookup data
# Added row group 286 to lookup data
# Added row group 287 to lookup data
# Lookup dataset created and saved to ../data/train/docid_lookup.parquet

# %%
import pyarrow.parquet as pq
import polars as pl

# Load the lookup dataset
lookup_df = pl.read_parquet("../data/train/docid_lookup.parquet")

# Load the Parquet file
parquet_file = pq.ParquetFile("../data/corpus/dataset.parquet")

# Function to retrieve a document by docid
def get_document_by_docid(docid: str):
    # Find the row group for the given docid
    row_group = lookup_df.filter(pl.col("docid") == docid).select("row_group").to_series(0)
    
    if row_group.is_empty():
        raise ValueError(f"Document with docid '{docid}' not found.")
    
    row_group_index = row_group[0]
    row_group_data = parquet_file.read_row_group(row_group_index).to_pandas()
    
    row_group_df = pl.from_pandas(row_group_data)
    document = row_group_df.filter(pl.col("docid") == docid)
    return document

docid = "D12123"
try:
    document = get_document_by_docid(docid)
    print(document)
except ValueError as e:
    print(e)
# Out:
# shape: (1, 3)
# ┌────────┬─────────────────────────────────┬─────────────────────────────────┐
# │ docid  ┆ title                           ┆ body                            │
# │ ---    ┆ ---                             ┆ ---                             │
# │ str    ┆ str                             ┆ str                             │
# ╞════════╪═════════════════════════════════╪═════════════════════════════════╡
# │ D12123 ┆ is there an age of accountabil… ┆ is there an age of accountabil… │
# └────────┴─────────────────────────────────┴─────────────────────────────────┘
